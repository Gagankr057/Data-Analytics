# %% [markdown]
# # SubQueries Assignment.

# %% [markdown]
# **Table Creation**
# ![Screenshot (108).png](data:image/png;base64,...)
#
# ![Screenshot (109).png](data:image/png;base64,...)
#
# ![Screenshot (111).png](data:image/png;base64,...)
#
# ![Screenshot (112).png](data:image/png;base64,...)

# %% [markdown]
# **Question 1 : Retrieve the names of employees who earn more than the average salary of all employees.**
#
# **Ans :**
#
# ![Screenshot (113).png](data:image/png;base64,...)

# %% [markdown]
# **Question 2 : Find the employees who belong to the department with the highest average salary.**
#
# **Ans :**
#
# ![Screenshot (114).png](data:image/png;base64,...)

# %% [markdown]
# **Question 3 : List all employees who have made at least one sale.**
#
# **Ans :**
#
# ![Screenshot (115).png](data:image/png;base64,...)

# %% [markdown]
# **Question 4 : Find the employee with the highest sale amount.**
#
# **Ans :**
#
# ![Screenshot (116).png](data:image/png;base64,...)

# %% [markdown]
# **Question 5 : Retrieve the names of employees whose salaries are higher than Shubham’s salary.**
#
# **Ans :**
#
# ![Screenshot (117).png](data:image/png;base64,...)

# %% [markdown]
# **Question 6 : Find employees who work in the same department as Abhishek.**
#
# **Ans :**
# ![Screenshot (118).png](data:image/png;base64,...)

# %% [markdown]
# **Question 7 : List departments that have at least one employee earning more than ₹60,000.**
#
# **Ans :**
#
# ![Screenshot (119).png](data:image/png;base64,...)

# %% [markdown]
# **Question 8 : Find the department name of the employee who made the highest sale.**
#
# **Ans :**
#
# ![Screenshot (120).png](data:image/png;base64,...)

# %% [markdown]
# **Question 9 : Retrieve employees who have made sales greater than the average sale amount.**
#
# **Ans :**
#
# ![Screenshot (121).png](data:image/png;base64,...)

# %% [markdown]
# **Question 10 : Find the total sales made by employees who earn more than the average salary.**
#
# **Ans :**
#
# ![Screenshot (122).png](data:image/png;base64,...)

# %% [markdown]
# **Question 11 : Find employees who have not made any sales.**
#
# **Ans :**  All employees made sale.
#
# ![Screenshot (123).png](data:image/png;base64,...)

# %% [markdown]
# **Question 12 : List departments where the average salary is above ₹55,000.**
#
# **Ans :**
#
# ![Screenshot (124).png](data:image/png;base64,...)

# %% [markdown]
# **Question 13 : Retrieve department names where the total sales exceed ₹10,000.**
#
# **Ans :**
#
# ![Screenshot (125).png](data:image/png;base64,...)

# %% [markdown]
# **Question 14 : Find the employee who has made the second-highest sale.**
#
# **Ans :**
#
# ![Screenshot (126).png](data:image/png;base64,...)

# %% [markdown]
# **Question 15 : Retrieve the names of employees whose salary is greater than the highest sale amount recorded.**
#
# **Ans :**
#
# ![Screenshot (127).png](data:image/png;base64,...)
