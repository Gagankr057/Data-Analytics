# %% [markdown]
# # Copilot with SQL and Excel Assignment

# %% [markdown]
# **Question 1 : Use Github Copilot to create a table SalesData whose columns are CustomerID, Name, Age, City,PurchaseAmount, PurchaseDate and then ask to insert 10,000 rows of random data.**
#
# **Ans :** ![Screenshot (279).png](data:image/png;base64,...)
#
# ![Screenshot (280).png](data:image/png;base64,...)

# %% [markdown]
# **Question 2 : Use Copilot to:**
# * **Find total sales per city**
# * **Top 5 cities by revenue**
#
# **Ans :** ![Screenshot (281).png](data:image/png;base64,...)
#
# ![Screenshot (282).png](data:image/png;base64,...)

# %% [markdown]
# **Question 3  : Ask Copilot:**
# * **Find customers with purchases above average**
#
# **Ans :**
#
# ![Screenshot (283).png](data:image/png;base64,...)

# %% [markdown]
# **Question 4 : Identify and handle missing values in the dataset using Copilot.**
#
# **Ans :** Solved in excel sheet and attached it.(Copilot with excel is not purchsed so i solved all manually)

# %% [markdown]
# **Question 5 : Task -**
# * **Identify duplicate rows**
# * **Remove duplicates using Copilot suggestion**
#
# **Ans :** Solved in excel sheet and attached it.(Copilot with excel is not purchsed so i solved all manually)

# %% [markdown]
# **Question 6 : Generate:**
# * **Column chart OR bar chart and Interpret which region has highest sales**
#
#
# **Ans :** Solved in excel sheet and attached it.(Copilot with excel is not purchsed so i solved all manually)

# %% [markdown]
# **Question 7 : Create a pivot table showing total sales by region and product.**
#
# **Ans :** Solved in excel sheet and attached it.(Copilot with excel is not purchsed so i solved all manually)

# %% [markdown]
# **Question 8 : Use Copilot to generate a new calculated column Total Sales**
#
#
# **Ans :** Solved in excel sheet and attached it.(Copilot with excel is not purchsed so i solved all manually)

# %% [markdown]
# **Question 9: Summarize the dataset and find the key insights.**
#
# **Ans 9 :**
#
# **Dataset Summary**
# * Total records: 550
#
# **Columns:**
#
# * Customer Name
# * Region
# * Product
# * Sales
# * Quantity
# * Order Date
# * Total Sales (created in Q8)
#
# **Data cleaning performed:**
# * Missing values handled
# * Invalid quantity values corrected
# * Duplicate rows removed
#
# **Key Insights**
# * Missing values were present in Customer Name, Region, Product, Sales, and Quantity columns.
# * 51 duplicate records were identified and removed.
# * The West region had the highest sales among the known regions.
# * Some records contained missing region information and were labeled as Unknown.
# * Product sales varied significantly across regions.
# *Creating the Total Sales column enabled better revenue analysis.
# * Data quality improved after cleaning and standardization.
#
#
# **Excel file is also attached**

# %% [markdown]
# **Question 10 : Generate VBA code using Copilot for cleaning data (removing duplicates, filling null values,
# format table).**
#
# **Ans :** VBA code was generated to automate data cleaning. The macro removes duplicate records, fills missing values, formats the header row, and auto-adjusts column widths. Automation improves efficiency and ensures
# consistent data preparation.
#
# **Excel file is attached with assignment**
