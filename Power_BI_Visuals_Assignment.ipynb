# %% [markdown]
# # Power BI Visuals Assignment

# %% [markdown]
# **Question 1 : Create a Card Visual to show Total Sales.**
#
# **Ans :** Total Sales is 12.64M
# ![Screenshot (160).png](data:image/png;base64,...)

# %% [markdown]
# **Question 2  : Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the highest sales?**
#
# **Ans :** The ship mode with the largest slice generates the highest sales is Standard Class.
# ![Screenshot (161).png](data:image/png;base64,...)

# %% [markdown]
# **Question 3 : Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any noticeable seasonal pattern in sales?**
#
# **Ans :**
# - The line chart shows an overall upward trend in sales over time, indicating business growth.
# - Sales tend to increase during the end of the year, especially around November and December, suggesting a seasonal pattern likely due to holiday and year-end demand.
# - Lower sales are generally observed in the early months of the year.
# - Yes, a seasonal pattern is noticeable.
#
# ![Screenshot (162).png](data:image/png;base64,...)

# %% [markdown]
# **Question 4 : Create a Bar Chart to compare Sales by Category.**
#
# **Ans :** The bar chart compares total sales across different product categories. The **Technology** category generates the highest sales, followed by **Furniture**, while **Office Supplies** has comparatively lower sales.
#
# ![Screenshot (163).png](data:image/png;base64,...)

# %% [markdown]
# **Question 5 : Create a Matrix Visual to display Sales by Month and Category and identify the month with the highest sales.**
#
# **Ans :** From the total values, it is observed that **December** records the highest overall sales with Sales value of **1,383,335.11**
#
#  ![Screenshot (164).png](data:image/png;base64,...)

# %% [markdown]
# **Question 6 : Create a Decomposition Tree for Sales Breakdown.**
#
# **Ans :** ![Screenshot (165).png](data:image/png;base64,...)

# %% [markdown]
# **Question 7 : Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers where high discounts resulted in negative profit?**
#
# **Ans :** Yes Outlier is ppresent.
#
# ![Screenshot (166).png](data:image/png;base64,...)

# %% [markdown]
# **Question 8 : Use a Funnel Chart to show the number of orders by Customer Segment.**
#
# **Ans :** ![Screenshot (167).png](data:image/png;base64,...)

# %% [markdown]
# **Question 9 : Use a Waterfall Chart to analyze how Profit changes by Category within the countries.**
#
# **Ans :** ![Screenshot (168).png](data:image/png;base64,...)

# %% [markdown]
# **Question 10 : Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month).**
#
# **Ans :** ![Screenshot (170).png](data:image/png;base64,...)
